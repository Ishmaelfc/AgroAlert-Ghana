# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib
import seaborn
import requests
import africastalking

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Scikit-learn:", sklearn.__version__)
print("Matplotlib:", matplotlib.__version__)
print("All libraries loaded successfully!")
# Out:
# NumPy: 2.5.0
# Pandas: 3.0.3
# Scikit-learn: 1.9.0
# Matplotlib: 3.11.0
# All libraries loaded successfully!

# %%
import ee

credentials = ee.ServiceAccountCredentials(
    email='agroalert-service@ee-ishmaelfc.iam.gserviceaccount.com',
    key_file='C:/Users/ELITE/Documents/AGROALERT/service_account.json'
)
ee.Initialize(credentials)
print("Google Earth Engine initialized successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import ee
#       2
# ----> 3 credentials = ee.ServiceAccountCredentials(
#       4     email='agroalert-service@ee-ishmaelfc.iam.gserviceaccount.com',
#       5     key_file='C:/Users/ELITE/Documents/AGROALERT/service_account.json'
#       6 )
#
# File c:\Users\ELITE\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ee\_helpers.py:53, in ServiceAccountCredentials(email, key_file, key_data)
#      51 # Assume anything that doesn't end in '.pem' is a JSON key.
#      52 if key_file and not key_file.endswith('.pem'):
# ---> 53   return service_account.Credentials.from_service_account_file(
#      54       key_file, scopes=oauth.SCOPES)
#      56 # If 'key_data' can be decoded as JSON, it's probably a raw JSON key.
#      57 if key_data:
#
# ...

# %%
import ee
import os

# Check if file exists
path = 'C:/Users/ELITE/Documents/AGROALERT/service_account.json'
print("File exists:", os.path.exists(path))
# Out:
# File exists: False

# %%
import os

for root, dirs, files in os.walk('C:/Users/ELITE/Documents'):
    for file in files:
        if file == 'service_account.json':
            print(os.path.join(root, file))

# %%
import os

for root, dirs, files in os.walk('C:/Users/ELITE'):
    for file in files:
        if file == 'service_account.json':
            print(os.path.join(root, file))

# %%
import ee

credentials = ee.ServiceAccountCredentials(
    email='agroalert-service@ee-ishmaelfc.iam.gserviceaccount.com',
    key_file='C:/Users/ELITE/Documents/AGROALERT/service_account.json'
)
ee.Initialize(credentials)
print("Google Earth Engine initialized successfully!")
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File c:\Users\ELITE\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\ee\data.py:359, in _execute_cloud_call(call, num_retries)
#     358 try:
# --> 359   return call.execute(num_retries=num_retries)
#     360 except googleapiclient.errors.HttpError as e:
#
# File c:\Users\ELITE\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\Users\ELITE\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
# ...

# %%
import os
print(os.path.exists('C:/Users/ELITE/Documents/AGROALERT/service_account.json'))
# Out:
# True

# %%
import ee

credentials = ee.ServiceAccountCredentials(
    email='agroalert-service@ee-ishmaelfc.iam.gserviceaccount.com',
    key_file='C:/Users/ELITE/Documents/AGROALERT/service_account.json'
)
ee.Initialize(credentials)
print("Google Earth Engine initialized successfully!")
# Out:
# Google Earth Engine initialized successfully!
